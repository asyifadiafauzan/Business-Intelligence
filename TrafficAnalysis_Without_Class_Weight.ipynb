# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random
import os
import joblib
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, SimpleRNN, Conv1D, GlobalMaxPooling1D, Dense, Input
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import seaborn as sns

# %%
os.environ["PYTHONHASHSEED"] = "42"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

random.seed(42)
np.random.seed(42)
tf.keras.utils.set_random_seed(42)

# %% [markdown]
# #Read The Data and windowing become per minute

# %%
def read_gate_toll_data(file_path, sheet="BI"):
    df = pd.read_excel(file_path, sheet_name=sheet, header=None, usecols="A:F")

    df.columns = ["Lane_A","Lane_B","Lane_C","Lane_D","Lane_E","Lane_F"]

    df = df.apply(lambda col: pd.to_datetime(col, unit="s", errors="coerce"))

    df_long = df.melt(var_name="Lane", value_name="Entry_Time").dropna()

    return df_long


def create_minute_counts(data):
    data = data.sort_values(["Lane", "Entry_Time"])
    data["Minute_Window"] = data["Entry_Time"].dt.floor("min")

    return (
        data.groupby(["Lane", "Minute_Window"])
        .size()
        .reset_index(name="Vehicle_Count")
    )


def fill_missing_minutes_per_lane(df):
    df["Minute_Window"] = pd.to_datetime(df["Minute_Window"])
    full_data = []

    for lane in df["Lane"].unique():
        lane_df = df[df["Lane"] == lane].copy()
        lane_df = lane_df.set_index("Minute_Window")

        full_range = pd.date_range(
            start=lane_df.index.min().floor("H"),
            periods=60,
            freq="1min"
        )

        lane_df = lane_df.reindex(full_range, fill_value=0)
        lane_df.index.name = "Minute_Window"
        lane_df = lane_df.reset_index()
        lane_df["Lane"] = lane

        full_data.append(lane_df)

    return pd.concat(full_data, ignore_index=True)

# %% [markdown]
# #create features from previous data

# %%
def create_features(df):
    df = df.sort_values(["Lane", "Minute_Window"]).copy()

    df["Delta"] = (
        df.groupby("Lane")["Vehicle_Count"]
        .diff()
        .fillna(0)
    )

    df["Rolling_Mean_3"] = (
        df.groupby("Lane")["Vehicle_Count"]
        .rolling(3, min_periods=1)
        .mean()
        .reset_index(level=0, drop=True)
    )

    df["Rolling_Mean_5"] = (
        df.groupby("Lane")["Vehicle_Count"]
        .rolling(5, min_periods=1)
        .mean()
        .reset_index(level=0, drop=True)
    )

    return df

# %% [markdown]
# #Create label based on 50% percentile, 50%=3

# %%
def create_high_low_label(df, percentile=50):
    df = df.sort_values(["Lane", "Minute_Window"]).copy()

    thresholds = (
        df.groupby("Lane")["Vehicle_Count"]
        .quantile(percentile / 100.0)
        .to_dict()
    )

    print(f"\nThresholds (percentile={percentile}):")
    for lane, value in thresholds.items():
        print(f"Lane {lane}: {value}")

    df["Traffic_Label"] = df.apply(
        lambda row: 1 if row["Vehicle_Count"] > thresholds[row["Lane"]] else 0,
        axis=1
    )

    return df

# %%
def create_sequences_per_lane(df, feature_cols, target_col, seq_length):
    X, y = [], []

    for lane in df["Lane"].unique():
        lane_df = df[df["Lane"] == lane].sort_values("Minute_Window")

        for i in range(len(lane_df) - seq_length):
            X.append(lane_df[feature_cols].iloc[i:i+seq_length].values)
            y.append(lane_df[target_col].iloc[i+seq_length])

    return np.array(X), np.array(y)

# %%
file_path = r"/content/data tol.xlsx"

data = read_gate_toll_data(file_path)
windowed_counts = create_minute_counts(data)
lane_counts = fill_missing_minutes_per_lane(windowed_counts)
lane_counts = create_high_low_label(lane_counts, percentile=50)
lane_counts = create_features(lane_counts)

# Save for Streamlit
lane_counts.to_csv(
    r"/content/lane_counts.csv",
    index=False
)
# Out:
# Thresholds (percentile=50):
# Lane Lane_A: 3.0
# Lane Lane_B: 3.0
# Lane Lane_C: 3.0
# Lane Lane_D: 3.0
# Lane Lane_E: 3.0
# Lane Lane_F: 3.0
# /tmp/ipykernel_24581/3741859878.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start=lane_df.index.min().floor("H"),
# /tmp/ipykernel_24581/3741859878.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start=lane_df.index.min().floor("H"),
# /tmp/ipykernel_24581/3741859878.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start=lane_df.index.min().floor("H"),
# /tmp/ipykernel_24581/3741859878.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start=lane_df.index.min().floor("H"),
# /tmp/ipykernel_24581/3741859878.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start=lane_df.index.min().floor("H"),
# /tmp/ipykernel_24581/3741859878.py:33: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start=lane_df.index.min().floor("H"),

# %% [markdown]
# #lane pattern analysis

# %%
def plot_traffic_per_lane(df):
    lanes = df["Lane"].unique()

    for lane in lanes:
        lane_df = df[df["Lane"] == lane].sort_values("Minute_Window")

        plt.figure()
        plt.plot(lane_df["Minute_Window"], lane_df["Vehicle_Count"])
        plt.title(f"Traffic Pattern - {lane}")
        plt.xlabel("Minute Window")
        plt.ylabel("Vehicle Count")
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
plot_traffic_per_lane(lane_counts)

# %%
def plot_combined_traffic_10min(df):
    df = df.copy()
    df["Minute_Window"] = pd.to_datetime(df["Minute_Window"])

    # Combine all lanes
    combined = (
        df.groupby("Minute_Window")["Vehicle_Count"]
        .sum()
        .reset_index()
    )

    # Resample to 10-minute intervals
    combined_10min = (
        combined.set_index("Minute_Window")
        .resample("10min")
        .sum()
        .reset_index()
    )

    plt.figure()
    sns.lineplot(
        data=combined_10min,
        x="Minute_Window",
        y="Vehicle_Count"
    )

    plt.title("Combined Traffic Every 10 Minutes (All Lanes)")
    plt.xlabel("Time")
    plt.ylabel("Total Vehicle Count")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
plot_combined_traffic_10min(lane_counts)

# %%
percent_steps = [0, 25, 50, 75, 100]

lane_percentiles = (
    lane_counts
    .groupby("Lane")["Vehicle_Count"]
    .quantile([p / 100 for p in percent_steps], interpolation="nearest")
    .unstack()
)

lane_percentiles.columns = [f"P{p}" for p in percent_steps]

print("\nVehicle Count Percentiles per Lane:")
print(lane_percentiles)
# Out:
# Vehicle Count Percentiles per Lane:
#         P0  P25  P50  P75  P100
# Lane
# Lane_A   0    0    3    5     6
# Lane_B   0    0    3    5     7
# Lane_C   0    0    3    5     7
# Lane_D   0    1    3    5     7
# Lane_E   0    0    3    5     6
# Lane_F   0    0    3    5     7

# %% [markdown]
# #proportion of the label 0=low 1=high

# %%
print(lane_counts["Traffic_Label"].value_counts(normalize=True))
# Out:
# Traffic_Label
# 0    0.55
# 1    0.45
# Name: proportion, dtype: float64

# %%
label_dist = lane_counts["Traffic_Label"].value_counts(normalize=True).sort_index()

plt.figure()
plt.bar(label_dist.index.astype(str), label_dist.values)
plt.xlabel("Traffic_Label")
plt.ylabel("Proportion")
plt.title("Traffic Label Distribution")
plt.show()

# %%
feature_cols = ["Vehicle_Count", "Delta",
                "Rolling_Mean_3", "Rolling_Mean_5"]

target_col = "Traffic_Label"

SEQ_LENGTH = 5

# %%
from tensorflow.keras.layers import Flatten
def build_rnn(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        SimpleRNN(8),
        Dense(1, activation="sigmoid")
    ])
    model.compile(
        optimizer=Adam(0.001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
            tf.keras.metrics.AUC(name="auc")
        ]
    )
    return model


def build_lstm(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(8),
        Dense(1, activation="sigmoid")
    ])
    model.compile(
        optimizer=Adam(0.001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
            tf.keras.metrics.AUC(name="auc")
        ]
    )
    return model


def build_cnn(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        Conv1D(16, 2, activation="relu"),
        GlobalMaxPooling1D(),
        Dense(8, activation="relu"),
        Dense(1, activation="sigmoid")
    ])
    model.compile(
        optimizer=Adam(0.001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
            tf.keras.metrics.AUC(name="auc")
        ]
    )
    return model



def build_ANN(input_shape):

    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Flatten())
    model.add(Dense(64, activation="relu"))
    model.add(Dense(32, activation="relu"))
    model.add(Dense(1, activation="sigmoid"))

    model.compile(
        optimizer=Adam(0.001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall"),
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    return model

# %%
lanes = lane_counts["Lane"].unique()
MODEL_SAVE_PATH = r"/content/Model Without class weight"
os.makedirs(MODEL_SAVE_PATH, exist_ok=True)

input_shape = (SEQ_LENGTH, len(feature_cols))

results = {
    "RNN": {"auc": [], "acc": []},
    "LSTM": {"auc": [], "acc": []},
    "CNN": {"auc": [], "acc": []},
    "ANN": {"auc": [], "acc": []}
}

# =============================
# CROSS-LANE VALIDATION
# =============================
for test_lane in lanes:

    print("\n==============================")
    print("TEST LANE :", test_lane)
    print("==============================")

    train_df = lane_counts[lane_counts["Lane"] != test_lane].copy()
    test_df  = lane_counts[lane_counts["Lane"] == test_lane].copy()

    scaler = MinMaxScaler()
    train_df[feature_cols] = scaler.fit_transform(train_df[feature_cols])
    test_df[feature_cols]  = scaler.transform(test_df[feature_cols])

    X_train, y_train = create_sequences_per_lane(
        train_df, feature_cols, target_col, SEQ_LENGTH
    )

    X_test, y_test = create_sequences_per_lane(
        test_df, feature_cols, target_col, SEQ_LENGTH
    )

    print("X_train:", X_train.shape)
    print("X_test :", X_test.shape)

    models = {
        "RNN": build_rnn(input_shape),
        "LSTM": build_lstm(input_shape),
        "CNN": build_cnn(input_shape),
        "ANN": build_ANN(input_shape)
    }

    for name, model in models.items():

        print("\nTraining:", name)

        history = model.fit(
            X_train,
            y_train,
            epochs=20,
            batch_size=8,
            validation_data=(X_test, y_test),
            shuffle=False,
            verbose=1
        )

        eval_results = model.evaluate(X_test, y_test, verbose=0)

        test_acc = eval_results[1]
        test_precision = eval_results[2]
        test_recall = eval_results[3]
        test_auc = eval_results[4]

        print("Accuracy :", round(test_acc,4))
        print("Precision:", round(test_precision,4))
        print("Recall   :", round(test_recall,4))
        print("AUC      :", round(test_auc,4))

        results[name]["auc"].append(test_auc)
        results [name]["acc"].append(test_acc)

        # =============================
        # SAVE TRAINING CURVES
        # =============================
        plt.figure()
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title(f'{name} Accuracy - Test {test_lane}')
        plt.legend(['Train', 'Validation'])
        plt.savefig(os.path.join(
            MODEL_SAVE_PATH,
            f"{name}_{test_lane}_accuracy.png"
        ))
        plt.close()

        plt.figure()
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title(f'{name} Loss - Test {test_lane}')
        plt.legend(['Train', 'Validation'])
        plt.savefig(os.path.join(
            MODEL_SAVE_PATH,
            f"{name}_{test_lane}_loss.png"
        ))
        plt.close()
# Out:
# ==============================
# TEST LANE : Lane_A
# ==============================
# X_train: (275, 5, 4)
# X_test : (55, 5, 4)
#
# Training: RNN
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.7382 - auc: 0.9248 - loss: 0.5344 - precision: 0.6188 - recall: 0.9739 - val_accuracy: 0.8364 - val_auc: 0.9731 - val_loss: 0.4769 - val_precision: 0.7097 - val_recall: 1.0000
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8400 - auc: 0.9175 - loss: 0.4804 - precision: 0.7320 - recall: 0.9739 - val_accuracy: 0.8909 - val_auc: 0.9704 - val_loss: 0.4190 - val_precision: 0.7857 - val_recall: 1.0000
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8618 - auc: 0.9100 - loss: 0.4456 - precision: 0.7619 - recall: 0.9739 - val_accuracy: 0.8909 - val_auc: 0.9683 - val_loss: 0.3758 - val_precision: 0.7857 - val_recall: 1.0000
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8582 - auc: 0.9071 - loss: 0.4221 - precision: 0.7639 - recall: 0.9565 - val_accuracy: 0.9091 - val_auc: 0.9683 - val_loss: 0.3455 - val_precision: 0.8148 - val_recall: 1.0000
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8655 - auc: 0.9306 - loss: 0.3170 - precision: 0.8000 - recall: 0.9043 - val_accuracy: 0.9091 - val_auc: 0.9752 - val_loss: 0.2221 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8727 - auc: 0.9324 - loss: 0.3115 - precision: 0.8077 - recall: 0.9130 - val_accuracy: 0.9091 - val_auc: 0.9725 - val_loss: 0.2187 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8836 - auc: 0.9340 - loss: 0.3064 - precision: 0.8168 - recall: 0.9304 - val_accuracy: 0.9091 - val_auc: 0.9738 - val_loss: 0.2159 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8836 - auc: 0.9358 - loss: 0.3027 - precision: 0.8168 - recall: 0.9304 - val_accuracy: 0.9091 - val_auc: 0.9738 - val_loss: 0.2139 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8873 - auc: 0.9363 - loss: 0.2997 - precision: 0.8231 - recall: 0.9304 - val_accuracy: 0.9091 - val_auc: 0.9725 - val_loss: 0.2120 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8909 - auc: 0.9370 - loss: 0.2968 - precision: 0.8295 - recall: 0.9304 - val_accuracy: 0.9091 - val_auc: 0.9731 - val_loss: 0.2109 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8945 - auc: 0.9380 - loss: 0.2947 - precision: 0.8308 - recall: 0.9391 - val_accuracy: 0.9091 - val_auc: 0.9731 - val_loss: 0.2098 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8982 - auc: 0.9387 - loss: 0.2926 - precision: 0.8372 - recall: 0.9391 - val_accuracy: 0.9091 - val_auc: 0.9731 - val_loss: 0.2087 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9018 - auc: 0.9391 - loss: 0.2906 - precision: 0.8438 - recall: 0.9391 - val_accuracy: 0.9091 - val_auc: 0.9738 - val_loss: 0.2086 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9018 - auc: 0.9399 - loss: 0.2887 - precision: 0.8438 - recall: 0.9391 - val_accuracy: 0.9091 - val_auc: 0.9731 - val_loss: 0.2084 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9018 - auc: 0.9401 - loss: 0.2868 - precision: 0.8438 - recall: 0.9391 - val_accuracy: 0.9091 - val_auc: 0.9725 - val_loss: 0.2084 - val_precision: 0.8400 - val_recall: 0.9545
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9018 - auc: 0.9404 - loss: 0.2851 - precision: 0.8438 - recall: 0.9391 - val_accuracy: 0.9091 - val_auc: 0.9731 - val_loss: 0.2082 - val_precision: 0.8400 - val_recall: 0.9545
# Accuracy : 0.9091
# Precision: 0.84
# Recall   : 0.9545
# AUC      : 0.9731
#
# ==============================
# TEST LANE : Lane_B
# ==============================
# X_train: (275, 5, 4)
# X_test : (55, 5, 4)
#
# Training: RNN
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8909 - auc: 0.9454 - loss: 0.2747 - precision: 0.8231 - recall: 0.9386 - val_accuracy: 0.8545 - val_auc: 0.9158 - val_loss: 0.3452 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8982 - auc: 0.9461 - loss: 0.2704 - precision: 0.8308 - recall: 0.9474 - val_accuracy: 0.8545 - val_auc: 0.9158 - val_loss: 0.3483 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8982 - auc: 0.9470 - loss: 0.2664 - precision: 0.8308 - recall: 0.9474 - val_accuracy: 0.8545 - val_auc: 0.9124 - val_loss: 0.3529 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8982 - auc: 0.9477 - loss: 0.2633 - precision: 0.8308 - recall: 0.9474 - val_accuracy: 0.8545 - val_auc: 0.9124 - val_loss: 0.3539 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8982 - auc: 0.9497 - loss: 0.2600 - precision: 0.8308 - recall: 0.9474 - val_accuracy: 0.8545 - val_auc: 0.9103 - val_loss: 0.3584 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8982 - auc: 0.9506 - loss: 0.2569 - precision: 0.8308 - recall: 0.9474 - val_accuracy: 0.8545 - val_auc: 0.9110 - val_loss: 0.3608 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8982 - auc: 0.9510 - loss: 0.2546 - precision: 0.8308 - recall: 0.9474 - val_accuracy: 0.8364 - val_auc: 0.9103 - val_loss: 0.3658 - val_precision: 0.7917 - val_recall: 0.8261
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9018 - auc: 0.9522 - loss: 0.2525 - precision: 0.8321 - recall: 0.9561 - val_accuracy: 0.8364 - val_auc: 0.9103 - val_loss: 0.3700 - val_precision: 0.7917 - val_recall: 0.8261
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9055 - auc: 0.9526 - loss: 0.2510 - precision: 0.8333 - recall: 0.9649 - val_accuracy: 0.8364 - val_auc: 0.9103 - val_loss: 0.3730 - val_precision: 0.7917 - val_recall: 0.8261
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9018 - auc: 0.9530 - loss: 0.2494 - precision: 0.8321 - recall: 0.9561 - val_accuracy: 0.8545 - val_auc: 0.9090 - val_loss: 0.3768 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9018 - auc: 0.9538 - loss: 0.2481 - precision: 0.8321 - recall: 0.9561 - val_accuracy: 0.8545 - val_auc: 0.9090 - val_loss: 0.3788 - val_precision: 0.8000 - val_recall: 0.8696
# Accuracy : 0.8545
# Precision: 0.8
# Recall   : 0.8696
# AUC      : 0.909
#
# ==============================
# TEST LANE : Lane_C
# ==============================
# X_train: (275, 5, 4)
# X_test : (55, 5, 4)
#
# Training: RNN
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3418 - auc: 0.1024 - loss: 0.9308 - precision: 0.3655 - recall: 0.7982 - val_accuracy: 0.3636 - val_auc: 0.0802 - val_loss: 0.8746 - val_precision: 0.3846 - val_recall: 0.8696
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8618 - auc: 0.9027 - loss: 0.4742 - precision: 0.7714 - recall: 0.9474 - val_accuracy: 0.8909 - val_auc: 0.9490 - val_loss: 0.4241 - val_precision: 0.8148 - val_recall: 0.9565
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8618 - auc: 0.9031 - loss: 0.4401 - precision: 0.7714 - recall: 0.9474 - val_accuracy: 0.8545 - val_auc: 0.9477 - val_loss: 0.3896 - val_precision: 0.7586 - val_recall: 0.9565
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8618 - auc: 0.9039 - loss: 0.4148 - precision: 0.7714 - recall: 0.9474 - val_accuracy: 0.8727 - val_auc: 0.9470 - val_loss: 0.3647 - val_precision: 0.7667 - val_recall: 1.0000
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8618 - auc: 0.9062 - loss: 0.3970 - precision: 0.7714 - recall: 0.9474 - val_accuracy: 0.8727 - val_auc: 0.9470 - val_loss: 0.3472 - val_precision: 0.7667 - val_recall: 1.0000
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8582 - auc: 0.9072 - loss: 0.3846 - precision: 0.7660 - recall: 0.9474 - val_accuracy: 0.8727 - val_auc: 0.9470 - val_loss: 0.3348 - val_precision: 0.7667 - val_recall: 1.0000
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8582 - auc: 0.9076 - loss: 0.3758 - precision: 0.7660 - recall: 0.9474 - val_accuracy: 0.8727 - val_auc: 0.9470 - val_loss: 0.3258 - val_precision: 0.7667 - val_recall: 1.0000
# Epoch 14/20
# ...
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8873 - auc: 0.9323 - loss: 0.3120 - precision: 0.8088 - recall: 0.9565 - val_accuracy: 0.8545 - val_auc: 0.9070 - val_loss: 0.3534 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8873 - auc: 0.9327 - loss: 0.3100 - precision: 0.8088 - recall: 0.9565 - val_accuracy: 0.8545 - val_auc: 0.9036 - val_loss: 0.3522 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8873 - auc: 0.9324 - loss: 0.3081 - precision: 0.8088 - recall: 0.9565 - val_accuracy: 0.8364 - val_auc: 0.9070 - val_loss: 0.3511 - val_precision: 0.7241 - val_recall: 0.9545
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8873 - auc: 0.9330 - loss: 0.3064 - precision: 0.8088 - recall: 0.9565 - val_accuracy: 0.8364 - val_auc: 0.9084 - val_loss: 0.3501 - val_precision: 0.7241 - val_recall: 0.9545
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8873 - auc: 0.9343 - loss: 0.3048 - precision: 0.8088 - recall: 0.9565 - val_accuracy: 0.8364 - val_auc: 0.9036 - val_loss: 0.3492 - val_precision: 0.7241 - val_recall: 0.9545
# Accuracy : 0.8364
# Precision: 0.7241
# Recall   : 0.9545
# AUC      : 0.9036
#
# Training: LSTM
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.5818 - auc: 0.3107 - loss: 0.6918 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.6000 - val_auc: 0.8588 - val_loss: 0.6619 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6436 - auc: 0.8978 - loss: 0.6464 - precision: 0.8148 - recall: 0.1913 - val_accuracy: 0.7818 - val_auc: 0.8960 - val_loss: 0.6246 - val_precision: 0.8125 - val_recall: 0.5909
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8691 - auc: 0.9220 - loss: 0.3378 - precision: 0.7883 - recall: 0.9391 - val_accuracy: 0.8545 - val_auc: 0.8988 - val_loss: 0.3686 - val_precision: 0.7500 - val_recall: 0.9545
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8727 - auc: 0.9224 - loss: 0.3355 - precision: 0.7899 - recall: 0.9478 - val_accuracy: 0.8545 - val_auc: 0.8994 - val_loss: 0.3657 - val_precision: 0.7500 - val_recall: 0.9545
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8727 - auc: 0.9223 - loss: 0.3334 - precision: 0.7899 - recall: 0.9478 - val_accuracy: 0.8545 - val_auc: 0.9008 - val_loss: 0.3630 - val_precision: 0.7500 - val_recall: 0.9545
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8727 - auc: 0.9233 - loss: 0.3316 - precision: 0.7899 - recall: 0.9478 - val_accuracy: 0.8545 - val_auc: 0.9015 - val_loss: 0.3606 - val_precision: 0.7500 - val_recall: 0.9545
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8727 - auc: 0.9225 - loss: 0.3300 - precision: 0.7899 - recall: 0.9478 - val_accuracy: 0.8545 - val_auc: 0.9008 - val_loss: 0.3584 - val_precision: 0.7500 - val_recall: 0.9545
# Accuracy : 0.8545
# Precision: 0.75
# Recall   : 0.9545
# AUC      : 0.9008
#
# Training: CNN
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5818 - auc: 0.8175 - loss: 0.6857 - precision: 0.5000 - recall: 0.9826 - val_accuracy: 0.8000 - val_auc: 0.9139 - val_loss: 0.6760 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8545 - auc: 0.9370 - loss: 0.6633 - precision: 0.7517 - recall: 0.9739 - val_accuracy: 0.8545 - val_auc: 0.9153 - val_loss: 0.6569 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8800 - auc: 0.9323 - loss: 0.6442 - precision: 0.7887 - recall: 0.9739 - val_accuracy: 0.8545 - val_auc: 0.9139 - val_loss: 0.6393 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8800 - auc: 0.9307 - loss: 0.6244 - precision: 0.7887 - recall: 0.9739 - val_accuracy: 0.8545 - val_auc: 0.9098 - val_loss: 0.6197 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8836 - auc: 0.9294 - loss: 0.6028 - precision: 0.7943 - recall: 0.9739 - val_accuracy: 0.8545 - val_auc: 0.9043 - val_loss: 0.5980 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8982 - auc: 0.9286 - loss: 0.5790 - precision: 0.8175 - recall: 0.9739 - val_accuracy: 0.8545 - val_auc: 0.9070 - val_loss: 0.5741 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8909 - auc: 0.9277 - loss: 0.5534 - precision: 0.8148 - recall: 0.9565 - val_accuracy: 0.8545 - val_auc: 0.9070 - val_loss: 0.5485 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8800 - auc: 0.9276 - loss: 0.5261 - precision: 0.8106 - recall: 0.9304 - val_accuracy: 0.8545 - val_auc: 0.9132 - val_loss: 0.5220 - val_precision: 0.7333 - val_recall: 1.0000
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9055 - auc: 0.9439 - loss: 0.2712 - precision: 0.8397 - recall: 0.9565 - val_accuracy: 0.8727 - val_auc: 0.9380 - val_loss: 0.3063 - val_precision: 0.7778 - val_recall: 0.9545
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9091 - auc: 0.9440 - loss: 0.2689 - precision: 0.8462 - recall: 0.9565 - val_accuracy: 0.8727 - val_auc: 0.9401 - val_loss: 0.3046 - val_precision: 0.7778 - val_recall: 0.9545
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9018 - auc: 0.9455 - loss: 0.2675 - precision: 0.8385 - recall: 0.9478 - val_accuracy: 0.8909 - val_auc: 0.9380 - val_loss: 0.3029 - val_precision: 0.8077 - val_recall: 0.9545
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9091 - auc: 0.9464 - loss: 0.2656 - precision: 0.8462 - recall: 0.9565 - val_accuracy: 0.8909 - val_auc: 0.9366 - val_loss: 0.3022 - val_precision: 0.8077 - val_recall: 0.9545
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9055 - auc: 0.9466 - loss: 0.2645 - precision: 0.8397 - recall: 0.9565 - val_accuracy: 0.8909 - val_auc: 0.9387 - val_loss: 0.3023 - val_precision: 0.8077 - val_recall: 0.9545
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9091 - auc: 0.9469 - loss: 0.2635 - precision: 0.8462 - recall: 0.9565 - val_accuracy: 0.8909 - val_auc: 0.9387 - val_loss: 0.3021 - val_precision: 0.8077 - val_recall: 0.9545
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9091 - auc: 0.9474 - loss: 0.2621 - precision: 0.8462 - recall: 0.9565 - val_accuracy: 0.8909 - val_auc: 0.9394 - val_loss: 0.3023 - val_precision: 0.8077 - val_recall: 0.9545
# Accuracy : 0.8909
# Precision: 0.8077
# Recall   : 0.9545
# AUC      : 0.9394

# %%
summary = {}

print("\n===== CROSS-LANE PERFORMANCE SUMMARY =====")

for model_name, metrics in results.items():
    mean_auc = np.mean(metrics["auc"])
    std_auc  = np.std(metrics["auc"])

    mean_acc = np.mean(metrics["acc"])
    std_acc  = np.std(metrics["acc"])

    summary[model_name] = {
        "mean_auc": mean_auc,
        "std_auc": std_auc,
        "mean_acc": mean_acc,
        "std_acc": std_acc
    }

    print(
        f"{model_name:5s} | "
        f"AUC: {mean_auc:.4f} ± {std_auc:.4f} | "
        f"ACC: {mean_acc:.4f} ± {std_acc:.4f}"
    )
# Out:
# ===== CROSS-LANE PERFORMANCE SUMMARY =====
# RNN   | AUC: 0.9184 ± 0.0308 | ACC: 0.8788 ± 0.0271
# LSTM  | AUC: 0.9203 ± 0.0294 | ACC: 0.8667 ± 0.0227
# CNN   | AUC: 0.9235 ± 0.0316 | ACC: 0.8727 ± 0.0492
# ANN   | AUC: 0.9420 ± 0.0218 | ACC: 0.8909 ± 0.0278

# %%
best_model_name = max(
    summary.keys(),
    key=lambda m: (
        (summary[m]["mean_auc"] - summary[m]["std_auc"]) +
        (summary[m]["mean_acc"] - summary[m]["std_acc"])
    )
)

print("BEST MODEL (Consistent AUC + ACC):", best_model_name)
# Out:
# BEST MODEL (Consistent AUC + ACC): ANN

# %%
# FINAL TRAINING (ALL LANES)

scaler = MinMaxScaler()
lane_counts[feature_cols] = scaler.fit_transform(lane_counts[feature_cols])

X_all, y_all = create_sequences_per_lane(
    lane_counts, feature_cols, target_col, SEQ_LENGTH
)

if best_model_name == "RNN":
    final_model = build_rnn(input_shape)
elif best_model_name == "LSTM":
    final_model = build_lstm(input_shape)
else:
    final_model = build_cnn(input_shape)

final_model.fit(
    X_all,
    y_all,
    epochs=20,
    batch_size=8,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6576 - auc: 0.8786 - loss: 0.6749 - precision: 0.5488 - recall: 0.9854
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8182 - auc: 0.9156 - loss: 0.6520 - precision: 0.7016 - recall: 0.9781
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8576 - auc: 0.9225 - loss: 0.6319 - precision: 0.7528 - recall: 0.9781
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - auc: 0.9225 - loss: 0.6107 - precision: 0.7571 - recall: 0.9781
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8727 - auc: 0.9230 - loss: 0.5862 - precision: 0.7746 - recall: 0.9781
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - auc: 0.9217 - loss: 0.5579 - precision: 0.7836 - recall: 0.9781
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - auc: 0.9215 - loss: 0.5280 - precision: 0.7870 - recall: 0.9708
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8818 - auc: 0.9217 - loss: 0.4988 - precision: 0.7917 - recall: 0.9708
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8697 - auc: 0.9220 - loss: 0.4716 - precision: 0.7866 - recall: 0.9416
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - auc: 0.9228 - loss: 0.4457 - precision: 0.7862 - recall: 0.9124
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8606 - auc: 0.9227 - loss: 0.4216 - precision: 0.7935 - recall: 0.8978
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - auc: 0.9226 - loss: 0.4008 - precision: 0.7974 - recall: 0.8905
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8545 - auc: 0.9229 - loss: 0.3840 - precision: 0.7987 - recall: 0.8686
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8576 - auc: 0.9231 - loss: 0.3705 - precision: 0.8000 - recall: 0.8759
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8576 - auc: 0.9233 - loss: 0.3600 - precision: 0.8000 - recall: 0.8759
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8545 - auc: 0.9239 - loss: 0.3519 - precision: 0.7987 - recall: 0.8686
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8576 - auc: 0.9245 - loss: 0.3455 - precision: 0.8000 - recall: 0.8759
# Epoch 18/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - auc: 0.9246 - loss: 0.3406 - precision: 0.8013 - recall: 0.8832
# Epoch 19/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8606 - auc: 0.9246 - loss: 0.3365 - precision: 0.8013 - recall: 0.8832
# Epoch 20/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8636 - auc: 0.9254 - loss: 0.3332 - precision: 0.8026 - recall: 0.8905

# %%
MODEL_FINAL_PATH = os.path.join(
    MODEL_SAVE_PATH,
    f"best_{best_model_name}_percentile50.h5"
)

SCALER_PATH = os.path.join(
    MODEL_SAVE_PATH,
    "scaler.save"
)

final_model.save(MODEL_FINAL_PATH)
joblib.dump(scaler, SCALER_PATH)

print("Final model saved to:", MODEL_FINAL_PATH)
print("Scaler saved to:", SCALER_PATH)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Final model saved to: /content/Model Without class weight/best_ANN_percentile50.h5
# Scaler saved to: /content/Model Without class weight/scaler.save
